# %% [markdown]
# ## Numpy practical

# %%
import numpy as np

# Load CSV while handling missing values and headers
data = np.genfromtxt("data.csv", delimiter=",", skip_header=1)

print("Data Loaded Successfully!")
print(data)
# Out:
# Data Loaded Successfully!
# [[51. 92. 14. 71. 60.]
#  [20. 82. 86. 74. 74.]
#  [87. 99. 23.  2. 21.]
#  [52.  1. 87. 29. 37.]
#  [ 1. 63. 59. 20. 32.]
#  [75. 57. 21. 88. 48.]
#  [90. 58. 41. 91. 59.]
#  [79. 14. 61. 61. 46.]
#  [61. 50. 54. 63.  2.]
#  [50.  6. 20. 72. 38.]
#  [17.  3. 88. 59. 13.]
#  [ 8. 89. 52.  1. 83.]
#  [91. 59. 70. 43.  7.]
#  [46. 34. 77. 80. 35.]
#  [49.  3.  1.  5. 53.]
#  [ 3. nan nan 62. 17.]
#  [89. 43. 33. 73. 61.]
#  [99. 13. 94. 47. 14.]
#  [71. 77. 86. 61. 39.]
#  [84. 79. 81. 52. 23.]
#  [25. 88. 59. 40. 28.]
#  [14. 44. 64. 88. 70.]
#  [ 8. 87.  0.  7. 87.]
#  [62. 10. 80.  7. 34.]
#  [34. 32.  4. 40. 27.]
#  [ 6. 72. 71. 11. 33.]
#  [32. 47. 22. 61. 87.]
#  [36. 98. 43. 85. 90.]
#  [34. 64. 98. nan 77.]
#  [ 2.  0.  4. 89. 13.]
#  [26.  8. 78. 14. 89.]
#  [41. 76. 50. 62. 95.]
#  [51. 95.  3. 93. 22.]
#  [14. 42. 28. 35. 12.]
#  [31. 70. 58. 85. 27.]
#  [65. 41. 44. 61. 56.]
#  [ 5. 27. 27. 43. 83.]
#  [29. 61. 74. 91. 88.]
# ...

# %%
np.sin(data)
# Out:
# array([[ 0.67022918, -0.77946607,  0.99060736,  0.95105465, -0.30481062],
#        [ 0.91294525,  0.31322878, -0.92345845, -0.98514626, -0.98514626],
#        [-0.82181784, -0.99920683, -0.8462204 ,  0.90929743,  0.83665564],
#        [ 0.98662759,  0.84147098, -0.82181784, -0.66363388, -0.64353813],
#        [ 0.84147098,  0.1673557 ,  0.63673801,  0.91294525,  0.55142668],
#        [-0.38778164,  0.43616476,  0.83665564,  0.0353983 , -0.76825466],
#        [ 0.89399666,  0.99287265, -0.15862267,  0.10598751,  0.63673801],
#        [-0.44411267,  0.99060736, -0.96611777, -0.96611777,  0.90178835],
#        [-0.96611777, -0.26237485, -0.55878905,  0.1673557 ,  0.90929743],
#        [-0.26237485, -0.2794155 ,  0.91294525,  0.25382336,  0.29636858],
#        [-0.96139749,  0.14112001,  0.0353983 ,  0.63673801,  0.42016704],
#        [ 0.98935825,  0.86006941,  0.98662759,  0.84147098,  0.96836446],
#        [ 0.10598751,  0.63673801,  0.77389068, -0.83177474,  0.6569866 ],
# ...
